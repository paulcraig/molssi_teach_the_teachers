# %% [markdown]
# ## MolSSI workshop
# ### August 8, 2019

# %%
3+7
# Out:
# 10

# %%
#variable_name = value
deltaH = -541.5 #kJ/mole
#You cannot save your units as part of your value
deltaS = 10.4 #kJ/mole K
temperature = 298 #Kelvin
deltaG = deltaH - temperature*deltaS

# %%
print(deltaG)
# Out:
# -3640.7000000000003

# %%
deltaG*1000
print(deltaG)
# Out:
# -3640.7000000000003

# %%
deltaG*1000
# Out:
# -3640700.0000000005

# %%
deltaG_J = deltaG*1000
print(deltaG)
print(deltaG_J)
# Out:
# -3640.7000000000003
# -3640700.0000000005

# %%
deltaG = deltaG*1000
print(deltaG)
# Out:
# -3640700.0000000005

# %%
deltaG = deltaH + temperature*deltaS
print(deltaG)
# Out:
# 2557.7000000000003

# %%
deltaG = deltaH - temperature*deltaS
print(deltaG)
# Out:
# -3640.7000000000003

# %%
deltaH, deltaS, temperature = -541.5, 10.4, 298

# %%
deltaG = deltaH - temperature * deltaS
print(deltaG)
# Out:
# -3640.7000000000003

# %%
type(deltaG)
# Out:
# float

# %%
deltaG_string = str(deltaG)

# %%
type(deltaG)
# Out:
# float

# %%
type(deltaG_string)
# Out:
# str

# %%
deltaG_str * 100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-8cfa1d85fd3e> in <module>
# ----> 1 deltaG_str * 100
#
# NameError: name 'deltaG_str' is not defined

# %%
deltaG_string * 100
# Out:
# '-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.7000000000003-3640.700
# ...

# %%
deltaG * 100
# Out:
# -364070.0

# %%
type(deltaG)
# Out:
# float

# %%
type(deltaG)
type(deltaG_string)
# Out:
# str

# %%
pring (type(deltaG))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-c14a7c4d96eb> in <module>
# ----> 1 pring (type(deltaG))
#
# NameError: name 'pring' is not defined

# %%
print(type(deltaG))
print(type(deltaG_string))
# Out:
# <class 'float'>
# <class 'str'>

# %%
energy_kcal = [-13.4, -2.7, 5.4, 42.1]
print(energy_kcal)
# Out:
# [-13.4, -2.7, 5.4, 42.1]

# %%
print(energy_kcal[1])
# Out:
# -2.7

# %%
print(energy_kcal[2])
# Out:
# 5.4

# %%
energy_cal = energy_kcal[1]*1000
print(energy_cal)
# Out:
# -2700.0

# %% [markdown]
# ## Taking slices

# %%
#a slice is a new list that is a subset of an old list
#new_list = list_name[start:end]
short_list = energy_kcal[0:2]
print(short_list)
# Out:
# [-13.4, -2.7]

# %%
len(energy_kcal)
# Out:
# 4

# %%
len(short_list)
# Out:
# 2

# %%
slice1 = energy_kcal[1:]
slice2 = energy_kcal[:3]
print("slice1 is", slice1)
print("slice2 is", slice2)
# Out:
# slice1 is [-2.7, 5.4, 42.1]
# slice2 is [-13.4, -2.7, 5.4]

# %%
energy_kcal[:2]
print(energy_kcal)
# Out:
# [-13.4, -2.7, 5.4, 42.1]

# %%
#for variable in list_name: #colon is required
#    do things wtih variable #indentation is required

# %%
for number in energy_kcal:
    kJ = number*4.184
    print(kJ)
# Out:
# -56.0656
# -11.296800000000001
# 22.593600000000002
# 176.1464

# %%
#list_name.append(new_thing)
energy_kilojoules = []
for number in energy_kcal:

    kJ = number*4.184
    energy_kilojoules.append(kJ)
print(energy_kilojoules)
# Out:
# [-56.0656, -11.296800000000001, 22.593600000000002, 176.1464]

# %%
negative_energy = []
positive_energy = []

for number in energy_kilojoules:
    if number < 0:
        negative_energy.append(number)
    else:
        positive_energy.append(number)
    
print(negative_energy)
print(positive_energy)
# Out:
# [-56.0656, -11.296800000000001]
# [22.593600000000002, 176.1464]

# %%
#File parsing group #1: Nicole Eyet, Julia Koeppe, Dejun Chen, Paul Craig

# %%
ls data
# Out:
# Untitled.ipynb             outfiles/
# benzene.xyz*               sapt.out*
# buckminsterfullerene.xyz*  water.xyz*
# distance_data_headers.csv*

# %%
pwd
# Out:
# '/Users/pac8612/Desktop/cms-workshop'

# %%
import os

ethanol_file = os.path.join('data', 'outfiles', 'ethanol.out')
print(ethanol_file)
# Out:
# data/outfiles/ethanol.out

# %%
os.path.abspath('data/outfiles/ethanol.out')
# Out:
# '/Users/pac8612/Desktop/cms-workshop/data/outfiles/ethanol.out'

# %%
outfile = open(ethanol_file,"r")
data = outfile.readlines()

# %%
type(data)
# Out:
# list

# %%
outfile.close()

# %%
print(data)
# Out:
# ['\n', '    -----------------------------------------------------------------------\n', '          Psi4: An Open-Source Ab Initio Electronic Structure Package\n', '                               Psi4 1.1 release\n', '\n', '                         Git: Rev {HEAD} add49b9 \n', '\n', '\n', '    R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,\n', '    A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,\n', '    R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,\n', '    H. R. McAlexander, A. Kumar, M. Saitow, X. Wang, B. P. Pritchard,\n', '    P. Verma, H. F. Schaefer III, K. Patkowski, R. A. King, E. F. Valeev,\n', '    F. A. Evangelista, J. M. Turney, T. D. Crawford, and C. D. Sherrill,\n', '    J. Chem. Theory Comput. in press (2017).\n', '    (doi: 10.1021/acs.jctc.7b00174)\n', '\n', '    -----------------------------------------------------------------------\n', '\n', '\n', '    Psi4 started on: Tuesday, 27 June 2017 12:10PM\n', '\n', '    Process
# ...

# %%
print(len(data))
# Out:
# 270

# %%
for line in data:
    print(line)
# Out:
#     -----------------------------------------------------------------------
#
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#
#                                Psi4 1.1 release
#
#
#
#                          Git: Rev {HEAD} add49b9
#
#
#
#
#
#     R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,
#
#     A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,
#
#     R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,
#
#     H. R. McAlexander, A. Kumar, M. Saitow, X. Wang, B. P. Pritchard,
#
#     P. Verma, H. F. Schaefer III, K. Patkowski, R. A. King, E. F. Valeev,
#
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, and C. D. Sherrill,
#
#     J. Chem. Theory Comput. in press (2017).
#
#     (doi: 10.1021/acs.jctc.7b00174)
#
#
#
#     -----------------------------------------------------------------------
#
#
#
#
#
#     Psi4 started on: Tuesday, 27 June 2017 12:10PM
#
#
#
#     Process ID:  10591
#
# ...

# %%
for line in data:
    if 'Final Energy' in line:
        energy_line = line
        print(energy_line)
# Out:
#   @DF-RHF Final Energy:  -154.09130176573018

# %%
energy_line.split()
# Out:
# ['@DF-RHF', 'Final', 'Energy:', '-154.09130176573018']

# %%
energy_line.split(':')
# Out:
# ['  @DF-RHF Final Energy', '  -154.09130176573018\n']

# %%
words = energy_line.split()

# %%
print(words)
# Out:
# ['@DF-RHF', 'Final', 'Energy:', '-154.09130176573018']

# %%
energy = words[3]
print(energy)
# Out:
# -154.09130176573018

# %%
energy + 50
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-7bda8dd3f95d> in <module>
# ----> 1 energy + 50
#
# TypeError: can only concatenate str (not "int") to str

# %%
energy = float(energy)
energy + 50
# Out:
# -104.09130176573018

# %%
energy = float(words[3])

# %%
for line in data:
    if 'Electrostatics' in line:
        energy_line = line
        print(energy_line)

# %%
import os

energy_file = os.path.join('data', 'sapt.out')
print(energy_file)
# Out:
# data/sapt.out

# %%
outfile2 = open(energy_file,"r")
data1 = energy_file.readlines()
type(data1)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-79-045c8b37ea2f> in <module>
# ----> 1 outfile2 = open(energy_file,"r")
#       2 data1 = energy_file.readlines()
#       3 type(data1)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/outfiles/sapt.out'

# %%
ls data
# Out:
# Untitled.ipynb             outfiles/
# benzene.xyz*               sapt.out*
# buckminsterfullerene.xyz*  water.xyz*
# distance_data_headers.csv*

# %%
import os

sapt_file = os.path.join('data', 'sapt.out')
print(sapt_file)
# Out:
# data/sapt.out

# %%
os.path.abspath('data/sapt.out')
# Out:
# '/Users/pac8612/Desktop/cms-workshop/data/sapt.out'

# %%
outfile2 = open(sapt_file, "r")
data2 = outfile2.readlines()

# %%
outfile2.close()

# %%
print(len(data2))
# Out:
# 1535

# %%
for line in data:
    print(line)
# Out:
#     -----------------------------------------------------------------------
#
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#
#                                Psi4 1.2.1 release
#
#
#
#                          Git: Rev {HEAD} 406f4de
#
#
#
#
#
#     R. M. Parrish, L. A. Burns, D. G. A. Smith, A. C. Simmonett,
#
#     A. E. DePrince III, E. G. Hohenstein, U. Bozkaya, A. Yu. Sokolov,
#
#     R. Di Remigio, R. M. Richard, J. F. Gonthier, A. M. James,
#
#     H. R. McAlexander, A. Kumar, M. Saitow, X. Wang, B. P. Pritchard,
#
#     P. Verma, H. F. Schaefer III, K. Patkowski, R. A. King, E. F. Valeev,
#
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, and C. D. Sherrill,
#
#     J. Chem. Theory Comput. 13(7) pp 3185--3197 (2017).
#
#     (doi: 10.1021/acs.jctc.7b00174)
#
#
#
#
#
#                          Additional Contributions by
#
#     P. Kraus, H. Kruse, M. H. Lechner, M. C. Schieber, and R. A. Shaw
#
#
#
# ...

# %%
for line in data:
    if 'Electrostatics' in line:
        electrostatics = line
        print(electrostatics)
# Out:
#     Electrostatics                 -3.59915058 [mEh]      -2.25850118 [kcal/mol]      -9.44956984 [kJ/mol]
#
#     Electrostatics sSAPT0          -3.59915058 [mEh]      -2.25850118 [kcal/mol]      -9.44956984 [kJ/mol]

# %%
electrostatics.split()
# Out:
# ['Electrostatics',
#  'sSAPT0',
#  '-3.59915058',
#  '[mEh]',
#  '-2.25850118',
#  '[kcal/mol]',
#  '-9.44956984',
#  '[kJ/mol]']

# %%
words = electrostatics.split()

# %%
print(words)
# Out:
# ['Electrostatics', 'sSAPT0', '-3.59915058', '[mEh]', '-2.25850118', '[kcal/mol]', '-9.44956984', '[kJ/mol]']

# %%
electro = words[4]
print("Electrostatics :", words[4], "kcal/mole")
# Out:
# Electrostatics : -2.25850118 kcal/mole

# %%
for line in data:
    if 'Electrostatics' in line:
        electrostatics = line
        print("Electrostatics :", words[4], "kcal/mole")
    if 'Exchange' in line:
        exchange = line
        print("Exchange :", words[4], "kcal/mole")
# Out:
# Electrostatics : -2.25850118 kcal/mole
# Exchange : -2.25850118 kcal/mole
# Electrostatics : -2.25850118 kcal/mole
# Exchange : -2.25850118 kcal/mole

# %%
for line in data:
    if 'Electrostatics' in line and not 'Electrostatics s' in line:
        electrostatics = line
        words = electrostatics.split()
        print("Electrostatics :", words[3], "kcal/mole")
    if 'Exchange' in line and not 'Exchange s' in line:
        exchange = line
        words2 = exchange.split()
        print("Exchange :", words2[3], "kcal/mole")
    if 'Induction' in line and '5216' in line:
        induction = line
        words3 = induction.split()
        print("Induction :", words3[3], "kcal/mole")
    if 'Dispersion' in line and '9446' in line:
        dispersion = line
        words4 = dispersion.split()
        print("Dispersion :", words4[3], "kcal/mole")
total_energy = float(words[3]) + float(words2[3]) + float(words3[3]) + float(words4[3])
print("Total Energy: ", total_energy, "kcal/mole")
# Out:
# Electrostatics : -2.25850118 kcal/mole
# Exchange : 2.27730198 kcal/mole
# Induction : -0.52169330 kcal/mole
# Dispersion : -0.94466770 kcal/mole
# Total Energy:  -1.4475602000000003 kcal/mole

# %%
saptout = open('data/sapt.out','r')
saptlines = saptout.readlines()
important_lines=[]
energies=[]
for line in saptlines:
    if 'Electrostatics    ' in line:
        electro_line = line
        important_lines.append(electro_line)
    if 'Exchange       ' in line:
        exchange_line = line
        important_lines.append(exchange_line)
    if 'Induction      ' in line:
        induction_line = line
        important_lines.append(induction_line)
    if 'Dispersion     ' in line:
        dispersion_line = line
        important_lines.append(dispersion_line)

#print(important_lines)

for line in important_lines:
    words = line.split()
    #print(words)
    energy_type = words[0]
    energy_kcal = float(words[3])
    energies.append(energy_kcal)
    print(energy_type, ':', energy_kcal, 'kcal/mole')

total_energy=energies[0]+energies[1]+energies[2]+energies[3]
print('Total Energy', ':', total_energy, 'kcal/mole')
# Out:
# Electrostatics : -2.25850118 kcal/mole
# Exchange : 2.27730198 kcal/mole
# Induction : -0.5216933 kcal/mole
# Dispersion : -0.9446677 kcal/mole
# Total Energy : -1.4475602000000003 kcal/mole
